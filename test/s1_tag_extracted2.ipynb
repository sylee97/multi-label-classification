# %%
import pandas as pd
# label_names.csv 열기
s1_tag_idx = pd.read_csv("C:\\Users\\NGN\\dev\\2022_NRF\\Multi-Label-Classification\\test\\s1_tag_idx.csv"
                      , encoding='utf-8')

# %%
real_extracted = pd.read_csv("C:\\Users\\NGN\\dev\\2022_NRF\\Multi-Label-Classification\\croller\\vid_dataset_real_extracted.csv")

# %%
real_extracted_list=list(real_extracted['imdb_id'])
print(real_extracted_list)
print(len(real_extracted_list))
# Out:
# ['tt0023427', 'tt0031381', 'tt0032910', 'tt0034492', 'tt0035896', 'tt0041716', 'tt0043379', 'tt0044926', 'tt0045125', 'tt0045810', 'tt0045888', 'tt0045963', 'tt0046183', 'tt0046303', 'tt0046672', 'tt0046912', 'tt0047396', 'tt0047673', 'tt0047834', 'tt0047849', 'tt0048545', 'tt0048728', 'tt0048801', 'tt0049261', 'tt0049966', 'tt0050419', 'tt0052905', 'tt0052918', 'tt0052948', 'tt0053172', 'tt0053221', 'tt0054047', 'tt0054195', 'tt0054331', 'tt0054494', 'tt0054847', 'tt0055257', 'tt0055304', 'tt0055471', 'tt0055614', 'tt0055928', 'tt0056923', 'tt0057076', 'tt0057197', 'tt0058329', 'tt0058385', 'tt0058571', 'tt0058672', 'tt0058777', 'tt0059017', 'tt0059125', 'tt0060345', 'tt0060397', 'tt0060522', 'tt0061512', 'tt0061584', 'tt0061791', 'tt0061810', 'tt0061852', 'tt0062168', 'tt0062512', 'tt0062803', 'tt0063385', 'tt0064603', 'tt0064782', 'tt0065054', 'tt0065063', 'tt0065088', 'tt0065112', 'tt0065134', 'tt0065207', 'tt0065724', 'tt0065738', 'tt0066206', 'tt0066808', 'tt0066995', 'tt006702
# ...

# %%
real_extrated_ds1= s1_tag_idx[s1_tag_idx['imdb_id'].isin(real_extracted_list)]
print(real_extrated_ds1)
# Out:
#        idx    imdb_id      tags_idx
# 0        0  tt0023427           1,0
# 2        2  tt0031381  3,20,32,0,23
# 3        3  tt0032910      43,18,12
# 5        5  tt0034492            43
# 6        6  tt0035896           1,0
# ...    ...        ...           ...
# 1193  1193  tt0116594            58
# 1194  1194  tt0116607         1,0,2
# 1196  1196  tt0116683     4,18,6,15
# 1197  1197  tt0116695        7,10,3
# 1198  1198  tt0116705            55
#
# [679 rows x 3 columns]

# %%
col1=list(real_extrated_ds1['imdb_id'])
print(col1)
print(len(col1))
# Out:
# ['tt0023427', 'tt0031381', 'tt0032910', 'tt0034492', 'tt0035896', 'tt0041716', 'tt0043379', 'tt0044926', 'tt0045125', 'tt0045810', 'tt0045888', 'tt0045963', 'tt0046183', 'tt0046303', 'tt0046672', 'tt0046912', 'tt0047396', 'tt0047673', 'tt0047834', 'tt0047849', 'tt0048545', 'tt0048728', 'tt0048801', 'tt0049261', 'tt0049966', 'tt0050419', 'tt0052905', 'tt0052918', 'tt0052948', 'tt0053172', 'tt0053221', 'tt0054047', 'tt0054195', 'tt0054331', 'tt0054494', 'tt0054847', 'tt0055257', 'tt0055304', 'tt0055471', 'tt0055614', 'tt0055928', 'tt0056923', 'tt0057076', 'tt0057197', 'tt0058329', 'tt0058385', 'tt0058571', 'tt0058672', 'tt0058777', 'tt0059017', 'tt0059125', 'tt0060345', 'tt0060397', 'tt0060522', 'tt0061512', 'tt0061584', 'tt0061791', 'tt0061810', 'tt0061852', 'tt0062168', 'tt0062512', 'tt0062803', 'tt0063385', 'tt0064603', 'tt0064782', 'tt0065054', 'tt0065063', 'tt0065088', 'tt0065112', 'tt0065134', 'tt0065207', 'tt0065724', 'tt0065738', 'tt0066206', 'tt0066808', 'tt0066995', 'tt006702
# ...

# %%
col2=list(real_extrated_ds1['tags_idx'])
print(col2)
print(len(col2))
# Out:
# ['1,0', '3,20,32,0,23', '43,18,12', '43', '1,0', '3', '1,14,49', '3', '5,14,0', '3,11', '5,0', '3', '9,6,18,14,12', '5,0,1,23', '30', '8,0,60', '21,8,22,0,60', '3', '50,6,11,0', '4,0', '4,1,3', '0,28', '3', '3,40,42,23', '23,5,6,3,2', '36', '25,0,28', '23', '0', '3,7', '9,4,8,6,10', '5,4,0,1', '3', '17,3,32,0,1', '33,6', '1', '5,4', '16,4,25,0,2', '3,23', '17,5,0,3,12', '9,4,0', '3,10,0', '4,0', '4,0', '23,3,31,0,2', '3,12,59', '3', '8,45', '4,32', '5', '5', '4,18,6,12,10', '4,8,6,60', '7', '26,28,10,42,15', '4,18,2', '7,11', '56', '43,12', '45,16,4,8', '4,6,0,1', '6,12,30', '3,0,23', '4', '4,7', '17', '7,11,12', '40,2', '8,45,0', '4,37,0,1', '41,1,3,2', '4,3', '16,25,0', '1,20,32', '4,7,11', '4,5,0', '21,4,7,8', '57,0,2', '37,2', '0,21,13,29,15', '16,21,29,2', '0', '3,40,32,58', '46,6,10,11', '38,42,5,0,28', '6,11,3', '4,3,34', '38,28,4,0,1', '42,4,8,13,0', '3,43,35', '19,63,4,0,1', '4,0,1', '4,7,13,0,1', '1,4,20,3', '9,14', '8', '5,4,13,0,1', '9,4,14', '1,7', '20,24,28,23', '7,28',
# ...
